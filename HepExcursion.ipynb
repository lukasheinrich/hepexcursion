# %%
import matplotlib.pyplot as plt
import problems

from decision_engine import run_smart_loop
from plotting import plot
# %matplotlib inline
# Out:
# /Users/lukasheinrich/Code/excursiondev/excvenv/lib/python3.6/site-packages/numpy/lib/index_tricks.py:184: ComplexWarning: Casting complex values to real discards the imaginary part
#   nn[k] = (nn[k]*step+start)

# %%
problem = getattr(problems,'simple_pyhf_problem')
pts_per_it = 1
for learner in run_smart_loop(problem, 2, 10, nsuggest = pts_per_it):
    plot(learner, nsuggest = pts_per_it)
    plt.show()
# Out:
# initialized
# /Users/lukasheinrich/Code/excursiondev/excvenv/lib/python3.6/site-packages/matplotlib/contour.py:1243: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# getting suggestion
# evaluating at [[0.17807897 0.77581642]]
# getting suggestion
# evaluating at [[0.23941613 0.19828585]]
# getting suggestion
# evaluating at [[0.62249875 0.21786278]]
# getting suggestion
# evaluating at [[0.82000301 0.83146321]]
# getting suggestion
# evaluating at [[0.6069161  0.48078071]]
# getting suggestion
# evaluating at [[0.88934705 0.88180628]]
# getting suggestion
# evaluating at [[0.15182924 0.11636693]]
# getting suggestion
# evaluating at [[0.44581415 0.41857259]]
# getting suggestion
# evaluating at [[0.1794358  0.20901276]]
# getting suggestion
# evaluating at [[0.65244445 0.65559223]]
# 82.53322911262512
